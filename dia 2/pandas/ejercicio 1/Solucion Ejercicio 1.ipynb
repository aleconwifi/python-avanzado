# %% [markdown]
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-3 col-md-3 col-lg-3">
# 	<!-- logo -->
#     <div class="img-responsive">
#       <img src="https://res.cloudinary.com/eventro/image/upload/v1668122125/image001.png" width="500" title="Python Avanzado Grupolotal" alt="Curso Python Avanzado">
#     </div>
# 	<!-- logo -->
#   </div>
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-6 col-md-6 col-lg-6">
# 	<!-- Pandas Tutorial -->
# 	  <center>
# 	    <br>
#         <h1>Dia 2</h1>
#  <h1>Ejercicio 1 Pandas</h1>
#         <br>
#         <br>
#         <strong> Python Avanzado </strong>
#          <br>
#         <strong>Alejandro Marcano Van Grieken</strong>
# 	  </center>
#     <!-- Pandas Tutorial -->
#   </div>
# <!-- ---------------------------------------------------- -->

# %% [markdown]
# ### Paso 1. Importa las librerías necesarias

# %%
import pandas as pd

# %% [markdown]
# ### Paso 2. Importa el dataset chiplotle.csv y guardalo en una varible df_ventas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aleconwifi/python-avanzado/master/dia%202/ejercicios/ejercicio%201/chipotle.csv')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Paso 3. Muestra los primeros 15 registros

# %%
df.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# 14         7         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 0                                                 NaN     $2.39
# 1                                        [Clementine]     $3.39
# 2                                             [Apple]     $3.39
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 14                                                NaN     $4.45

# %% [markdown]
# ### Paso 4. Muestra los últimos 10 registros de df_ventas

# %%
df.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# ### Paso 5. ¿Cuántos registros hay en el conjunto de datos?

# %%
len(df)
# Out:
# 4622

# %%
# Solución 2
df.shape[0]
# Out:
# 4622

# %% [markdown]
# ### Paso 6. ¿Qué cantidad de columnas hay en el dataset?

# %%
df.shape[1]
# Out:
# 5

# %% [markdown]
# ### Paso 7. Imprime el nombre de todas las columnas

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Paso 8. Seleccione las columnas "item_name" e "item_price" de las filas 10 a la 15

# %%
df.loc[10:15, ['item_name', 'item_price']]
# Out:
#                                 item_name item_price
# 10                    Chips and Guacamole     $4.45
# 11                   Chicken Crispy Tacos     $8.75
# 12                     Chicken Soft Tacos     $8.75
# 13                           Chicken Bowl    $11.25
# 14                    Chips and Guacamole     $4.45
# 15  Chips and Tomatillo-Green Chili Salsa     $2.39

# %% [markdown]
# ### Paso 9. Seleccione en df_ventas de la fila 3 a la 7 y de la columna de 3 a la 5

# %%
df.iloc[3:8, 2:5]
# Out:
#                                item_name  \
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl
# 5                           Chicken Bowl
# 6                          Side of Chips
# 7                          Steak Burrito
#
#                                   choice_description item_price
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Paso 10. Seleccione en df_ventas cada fila después de la  fila 1000 y todas las columnas.

# %%
df.loc[1000:, :]
# Out:
#       order_id  quantity           item_name  \
# 1000       411         1        Chicken Bowl
# 1001       411         1        Chicken Bowl
# 1002       412         1       Bottled Water
# 1003       412         1       Bottled Water
# 1004       412         1        Chicken Bowl
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1000  [Roasted Chili Corn Salsa (Medium), [Rice, Che...     $8.49
# 1001  [Roasted Chili Corn Salsa (Medium), [Black Bea...     $8.49
# 1002                                                NaN     $1.50
# 1003                                                NaN     $1.50
# 1004  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...     $8.75
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [3622 rows x 5 columns]

# %%
df.tail(3622)
# Out:
#       order_id  quantity           item_name  \
# 1000       411         1        Chicken Bowl
# 1001       411         1        Chicken Bowl
# 1002       412         1       Bottled Water
# 1003       412         1       Bottled Water
# 1004       412         1        Chicken Bowl
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1000  [Roasted Chili Corn Salsa (Medium), [Rice, Che...     $8.49
# 1001  [Roasted Chili Corn Salsa (Medium), [Black Bea...     $8.49
# 1002                                                NaN     $1.50
# 1003                                                NaN     $1.50
# 1004  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...     $8.75
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [3622 rows x 5 columns]

# %% [markdown]
# ### Paso 11. ¿Cuál/Cuáles son los productos menos vendido y su cantidad?

# %%
df_producto = df.groupby('item_name').sum()
df_producto.sort_values(['quantity']).head(3)
# Out:
#                                    order_id  quantity
# item_name
# Carnitas Salad                         1500         1
# Veggie Crispy Tacos                     668         1
# Chips and Mild Fresh Tomato Salsa       279         1

# %% [markdown]
# ### Paso 12. ¿Cuál es el artículo más vendido?

# %%
df_producto = df.groupby('item_name').sum()
df_producto.sort_values(['quantity'], ascending='False').head(1)
# Out:
#                 order_id  quantity
# item_name
# Carnitas Salad      1500         1

# %% [markdown]
# ### Paso 13. ¿Cuántos artículos fueron comprados en total?

# %%
print('La cantidad total es', df.quantity.sum())
# Out:
# La cantidad total es 4972

# %% [markdown]
# ### Paso 14. Convierta el precio de un artículo en un  float

# %% [markdown]
# #### Paso 14.a. Verifique el tipo de dato del precio del artículo

# %%
df_ventas = pd.read_csv('https://raw.githubusercontent.com/aleconwifi/python-avanzado/master/dia%202/ejercicios/ejercicio%201/chipotle.csv')
df_ventas.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#Solución 1
df_ventas['item_price'] = df_ventas['item_price'].str.strip('$')

# %%
#Solución 2
df_ventas['item_price'] = df_ventas['item_price'].astype(float)
df_ventas['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# #### Paso 14.b. Cree una función lambda y cambie el tipo de precio del artículo

# %% [markdown]
# #### Paso 14.c. Vuelve a verificar el tipo de dato del precio del artículo

# %%
#Solución 1

# %%
#Solución 2
type(df['item_price'][0])
# Out:
# numpy.float64

# %% [markdown]
# ### Paso 15. ¿Cuánto fue la ganancia total en el dataset? (Ganancia = Precio * Cantidad de Artículos Vendidos)

# %%
df['ganancia'] = df['quantity'] * df['item_price']

df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  ganancia
# 0                                                NaN        2.39      2.39
# 1                                       [Clementine]        3.39      3.39
# 2                                            [Apple]        3.39      3.39
# 3                                                NaN        2.39      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98     33.96

# %%
df['ganancia'].sum()
# Out:
# 39237.02

# %% [markdown]
# ### Paso 16. ¿Cuántos pedidos se hicieron en el período? (Varios productos de un mismo pedido tienen el mismo order_id)

# %%
df['order_id'].value_counts().count()
# Out:
# 1834

# %% [markdown]
# ### Paso 17. ¿Cuál es el monto promedio de ingresos por pedido?

# %%
# Solución 1
monto_pedido = df.groupby('order_id').sum().ganancia

monto_pedido.mean()
# Out:
# 21.39423118865867

# %%
# Solución 2

# %% [markdown]
# ### Paso 18. ¿Cuántos artículos diferentes se venden?

# %%
df.item_name.value_counts().count()
# Out:
# 50

# %%
len(df.item_name.unique())
# Out:
# 50

# %% [markdown]
# ### Paso 19. ¿Cuál fue la cantidad del artículo más caro pedido?

# %%
df.sort_values(['item_price'], ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  ganancia
# 3598       44.25    663.75

# %% [markdown]
# ###  Paso 20. Selecciona los pedidos que hayan comprado entre 3 y 8 productos (incluyendo 3 y 8)

# %%
df_agrupado = df.groupby('order_id').sum()
df_agrupado [(df_agrupado['quantity'] >= 3) & (df_agrupado['quantity'] <= 8)]
# Out:
#           quantity  item_price  ganancia
# order_id
# 1                4       11.56     11.56
# 9                3       10.67     12.85
# 18               4       24.90     24.90
# 20               4       36.20     36.20
# 21               3       23.36     23.36
# ...            ...         ...       ...
# 1827             5       32.95     32.95
# 1828             3       14.45     14.45
# 1829             3       24.25     24.25
# 1831             3       12.90     12.90
# 1834             3       28.75     28.75
#
# [724 rows x 3 columns]

# %% [markdown]
# ### Paso 21. ¿Cuántas veces se ordenó una Veggie Salad Bowl?

# %%
len(df[df['item_name'] == "Veggie Salad Bowl"])
# Out:
# 18

# %% [markdown]
# ###  Paso 22. ¿Cuántas veces alguien ordenó más de una Canned Soda?
